# %% [markdown]
# # Introduction:
# Study methods including active recall and spaced repetition involve the usage of repetition in order to increase students’ understanding of the subject material. Our chosen standardized dataset titled “User Knowledge Modeling” measures several variables that could possibly contribute to students’ knowledge on the subject of Electrical DC Machines.
# The predictive question we would like to answer is, “How does the degree of study time for goal object materials, the degree of repetition for goal object materials and exam performance contribute to the user’s level of knowledge regarding a subject?”
# The dataset we plan to use contains anonymous data in the following variables: degree of study time for the main subject (electrical DC machines), degree of repetition in studying for the main subject, the degree of study time for related topics, the exam performance of user for related topics, the exam performance for the main subject and the student’s overall knowledge levels.

# %% [markdown]
# # Preliminary exploratory data analysis

# %%
library(tidyverse)

# %%
#Read dataset from web
user_knowledge_data <- read_csv("https://raw.githubusercontent.com/trinityma/dsci100project/main/DDData_User_Modeling_Dataset_Hamdi%20Tolga%20KAHRAMAN%202%20(1).csv")
# Out:
# New names:
# • `` -> `...7`
# • `` -> `...8`
# Rows: 258 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): UNS, Attribute Information:
# dbl (5): STG, SCG, STR, LPR, PEG
# lgl (2): ...7, ...8
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#Clean and wrangle data into a tidy format
user_knowledge_data <- user_knowledge_data |> select(STG,SCG,STR,LPR,PEG,UNS) |> mutate(UNS=as_factor(UNS))
user_knowledge_data
# Out:
#     STG   SCG   STR  LPR  PEG  UNS
# 1   0.00  0.000 0.00 0.00 0.00 very_low
# 2   0.08  0.080 0.10 0.24 0.90 High
# 3   0.06  0.060 0.05 0.25 0.33 Low
# 4   0.10  0.100 0.15 0.65 0.30 Middle
# 5   0.08  0.080 0.08 0.98 0.24 Low
# 6   0.09  0.150 0.40 0.10 0.66 Middle
# 7   0.10  0.100 0.43 0.29 0.56 Middle
# 8   0.15  0.020 0.34 0.40 0.01 very_low
# 9   0.20  0.140 0.35 0.72 0.25 Low
# 10  0.00  0.000 0.50 0.20 0.85 High
# 11  0.18  0.180 0.55 0.30 0.81 High
# 12  0.06  0.060 0.51 0.41 0.30 Low
# 13  0.10  0.100 0.52 0.78 0.34 Middle
# 14  0.10  0.100 0.70 0.15 0.90 High
# 15  0.20  0.200 0.70 0.30 0.60 Middle
# 16  0.12  0.120 0.75 0.35 0.80 High
# 17  0.05  0.070 0.70 0.01 0.05 very_low
# 18  0.10  0.250 0.10 0.08 0.33 Low
# 19  0.15  0.320 0.05 0.27 0.29 Low
# 20  0.20  0.290 0.25 0.49 0.56 Middle
# 21  0.12  0.280 0.20 0.78 0.20 Low
# 22  0.18  0.300 0.37 0.12 0.66 Middle
# 23  0.10  0.270 0.31 0.29 0.65 Middle
# 24  0.18  0.310 0.32 0.42 0.28 Low
# ...

# %%
#Summarize the data to report the number of observations in each UNS class
uns_counts <- user_knowledge_data |>
                        group_by(UNS) |>
                        summarize(count = n())

uns_counts
# Out:
#   UNS      count
# 1 very_low 24
# 2 High     63
# 3 Low      83
# 4 Middle   88

# %%
#visualize the amount of training data for each UNS class

options(repr.plot.width=8, repr.plot.height=6)

uns_counts_plot <- ggplot(uns_counts, aes(x = UNS, y = count)) +
                    geom_bar(stat = "identity") +
                    labs(x = "Knowledge Level of User (UNS)", y = "Count") +
                    ggtitle("Number of observations in each UNS class")

uns_counts_plot
# Out:
# plot without title

# %%
#visualize the distribution of each predictor

options(repr.plot.width=8, repr.plot.height=6)

stg_distribution <- user_knowledge_data |>
                    ggplot(aes(x = STG)) +
                    geom_histogram() +
                    labs(x = "Degree of Study Time for Goal Object materials (STG)", y = "Count") +
                    ggtitle("Distribution of STG")

scg_distribution <- user_knowledge_data |>
                    ggplot(aes(x = SCG)) +
                    geom_histogram() +
                    labs(x = "Degree of Repetition Number of User for Goal Object Materials (SCG)", y = "Count") +
                    ggtitle("Distribution of SCG")

peg_distribution <- user_knowledge_data |>
                    ggplot(aes(x = PEG)) +
                    geom_histogram() +
                    labs(x = "Exam Performance of User for Goal Objects (PEG)", y = "Count") +
                    ggtitle("Distribution of PEG")

stg_distribution
scg_distribution
peg_distribution
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %% [markdown]
# # Methods:
# We will be using a scatterplot that that will include the three variables i.e The degree of study time for goal object materials(STG) ,The degree of repetition number of user for goal object materials(SCG) and The exam performance of user for goal objects(PEG) using these 3 variables we hope to use the scatterplot along with classification to try and predict The knowledge level of user(UNS). Classifying these parameters and modeling our classifier we will be able to use these 3 parameters and come up with a prediction for the student’s overall knowledge levels. We will use a testing and training set and train our model with respect to the training data set and modify it to make it as accurate as possible. Once we are satisfied with our classifier model we will test it on the testing data set to make sure of its efficiency.

# %% [markdown]
# We expect to find a positive relationship between the degree of repetition, exam performance, study time and a student’s degree of knowledge on the subject material. We expect these 3 variables to have a strong positive relationship with UNS ie the higher the value of these variables the higher is the knowledge of the user.

# %% [markdown]
# The findings we hope to find will give us the relationship  between the degree of repetition, exam performance, study time and a student’s degree of knowledge on the subject material. Looking at the results we will be able to figure out which variable is positively related to a student’s degree of knowledge on the subject material and which variable does not affect it as much.

# %% [markdown]
# Future questions include: how long should be the break between repetition when studying in order to achieve maximum understanding? Is there a value of study time where too much becomes detrimental? What is the most efficient way a student can increase his degree of knowledge on the subject?
